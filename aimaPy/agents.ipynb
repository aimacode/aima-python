# %%
import agents
# Out:
# ---------------------------------------------------------------------------
# SystemError                               Traceback (most recent call last)
# <ipython-input-1-c3d75f10577d> in <module>()
# ----> 1 import agents
#
# /Users/jeff/git/aima-python/aimaPy/agents.py in <module>()
#      36 # Speed control in GUI does not have any effect -- fix it.
#      37
# ---> 38 from . utils import *
#      39 import random
#      40 import copy
#
# SystemError: Parent module '' not loaded, cannot perform relative import
