# %%
import search
# Out:
# ---------------------------------------------------------------------------
# SystemError                               Traceback (most recent call last)
# <ipython-input-1-22bec47fba30> in <module>()
# ----> 1 import search
#
# /Users/jeff/git/aima-python/aimaPy/search.py in <module>()
#       6
#       7
# ----> 8 from . utils import *
#       9 import math
#      10 import random
#
# SystemError: Parent module '' not loaded, cannot perform relative import
